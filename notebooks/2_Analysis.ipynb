# %% [markdown]
# # Analysis

# %%
import bestreads.text as text
import pandas as pd

datadir = '../data/processed/'
processed_data_train = pd.read_csv(
    datadir + 'goodreads_books_train_processed.csv')
processed_data_test = pd.read_csv(
    datadir + 'goodreads_books_test_processed.csv')
tf_idf_table = pd.read_csv(
    datadir + 'tf_idf_table_train.csv')

# %%
genre_and_votes_train = processed_data_train[['genre_1', 'votes_1']]
genre_and_votes_test = processed_data_test[['genre_1', 'votes_1']]
cleaned_descriptions_train = processed_data_train['cleaned_descriptions']
cleaned_descriptions_test = processed_data_test['cleaned_descriptions']

# %%
tf_idf_table.head()
# Out:
#       word  Social Issues  Textbooks  Philosophy  Suspense  World War II  \
# 0    jimmi       0.029893   0.000000    0.000000  0.000000      0.000000
# 1     reev       0.066318   0.000000    0.000000  0.000000      0.000000
# 2       hi       0.009979   0.001744    0.003034  0.004364      0.001421
# 3     luck       0.021380   0.000000    0.000000  0.000000      0.000666
# 4  wildlif       0.032555   0.000000    0.000000  0.000000      0.000000
#
#    Adult Fiction  Paranormal      Epic  Womens Fiction  ...  New York  \
# 0       0.000000    0.000000  0.000000        0.000211  ...  0.000000
# 1       0.000000    0.000000  0.000000        0.000000  ...  0.000000
# 2       0.003667    0.002613  0.003647        0.000906  ...  0.001648
# 3       0.000102    0.000088  0.000000        0.000252  ...  0.000000
# 4       0.000000    0.000000  0.000000        0.000000  ...  0.000000
#
#    Realistic Fiction  Linguistics  Teaching  Fan Fiction  Inspirational  \
# ...
